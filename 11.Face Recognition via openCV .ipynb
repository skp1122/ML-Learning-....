# %%
# !pip install cv opencv-python
# Out:
# ...
#   Using cached cv-1.0.0-py3-none-any.whl (7.3 kB)
# ...

# %%
import cv2

# %%
# Read on Image

img = cv2.imread('./images/img.jpg')
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) ##converted from bgr to rgb

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)
plt.show()
plt.imshow(newImg)
plt.show()

# %%
print(img) #it'll show the image matrix
# Out:
# [[[ 83 102  87]
#   [ 83 102  87]
#   [ 81 100  85]
#   ...
#   [122 150 161]
#   [102 128 144]
#   [ 86 112 128]]
#
#  [[ 85 104  89]
#   [ 83 102  87]
#   [ 79  98  83]
#   ...
#   [122 150 161]
#   [103 129 145]
#   [ 88 114 130]]
#
#  [[ 87 105  88]
#   [ 83 101  84]
#   [ 80  98  81]
#   ...
#   [135 163 174]
#   [114 140 156]
#   [ 99 125 141]]
#
#  ...
#
#  [[ 49  59  76]
#   [ 47  57  74]
#   [ 58  67  81]
#   ...
#   [ 21  54  73]
#   [ 22  55  74]
#   [ 23  56  75]]
#
#  [[ 46  56  73]
#   [ 51  61  78]
#   [ 71  80  94]
#   ...
#   [ 21  54  73]
#   [ 22  55  74]
#   [ 24  57  76]]
#
#  [[ 39  49  66]
#   [ 53  63  80]
#   [ 85  94 108]
#   ...
#   [ 22  55  74]
#   [ 24  57  76]
#   [ 26  59  78]]]

# %%
## displaying image directly via opencv
import cv2

img = cv2.imread('./images/img.jpg')
gray = cv2.imread('./images/img.jpg',cv2.IMREAD_GRAYSCALE)

cv2.imshow('Bird Image',img)
cv2.imshow('Gray Bird Image',gray)

cv2.waitKey(10005) ## 0 means waiting image for infinite time
cv2.destroyAllWindows() ## afer time given in waitkey,it will destroyed itself
